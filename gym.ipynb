# %% [markdown]
# <a href="https://colab.research.google.com/github/Lubricy/notebooks/blob/master/gym.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade --quiet tensorflow_probability
# !apt-get install xvfb -qq

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import tensorflow_probability as tfp
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers

print(tf.version.VERSION)
print(tf.test.gpu_device_name())
# Out:
# TensorFlow 2.x selected.
# 2.1.0-rc1
# /device:GPU:0

# %%
# Make video
# Set up fake display; otherwise rendering will fail
import os
os.system("Xvfb :1 -screen 0 1024x768x24 &")
os.environ['DISPLAY'] = ':1'
# !mkdir -p videos

# %%
import os
import gym
from datetime import datetime
from gym.wrappers.monitoring.video_recorder import VideoRecorder
def record_video(env_id, model, video_length=500, prefix='', video_folder='videos/'):
  env = gym.make(env_id)
  timestamp = datetime.now().strftime('%Y%m%d_%H%M%S%f')
  filename = f"{f'{prefix}-' if prefix else ''}{env_id}-{timestamp}.mp4"
  with VideoRecorder(env, path=os.path.join(video_folder, )) as recorder:
    obs = env.reset()
    for i in range(video_length):
      env.render()
      recorder.capture_frame()
      action, _ = model.predict(obs)
      obs, _, _, _ = env.step(action)
  
  env.close()

# %%
from pathlib import Path
import base64
from IPython import display as D

# Display video
def show_videos(video_path='', prefix=''):
  html = []
  for mp4 in Path(video_path).glob("{}*.mp4".format(prefix)):
      video_b64 = base64.b64encode(mp4.read_bytes())
      html.append('''<video alt="{}" autoplay 
                    loop controls style="height: 400px;">
                    <source src="data:video/mp4;base64,{}" type="video/mp4" />
                </video>'''.format(mp4, video_b64.decode('ascii')))
  D.display(D.HTML(data="<br>".join(html)))

# %%
env =

# %%
show_videos('videos', 'test')
# Out:
# <video alt="videos/test.mp4" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>
